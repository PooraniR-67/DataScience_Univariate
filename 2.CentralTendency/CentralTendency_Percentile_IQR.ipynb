# %%
from Univariate import Univariate
import pandas as pd

# %%
dataset = pd.read_csv("Placement_Data_Full_Class.csv")
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
 def quanQual(dataset):
        qual = []
        quan = []
        for columnName in dataset.columns:
            if (dataset[columnName].dtype == 'O'):
                qual.append(columnName)
            else:
                quan.append(columnName)  
        return quan,qual

# %%
quan,qual = quanQual(dataset)
print(quan,"\n",qual)
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
#  ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %% [markdown]
# #Central Tendency

# %%
#to find Mean, Median, Mode for a single column
mean = dataset["ssc_p"].mean()
median = dataset["ssc_p"].median()
mode = dataset["ssc_p"].mode()[0]
print(mean,"\n",median,"\n",mode)
# Out:
# 67.30339534883721
#  67.0
#  62.0

# %%
# For multiple column and to store the output values in a table

tbl_format = pd.DataFrame(index=["Mean", "Median", "Mode"], columns = quan)
tbl_format
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
#To access particular value(cell) from the table
tbl_format["hsc_p"]["Mode"]
# Out:
# nan

# %%
#to assign the value for that cell
tbl_format["hsc_p"]["Mode"] = 90
tbl_format
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4852\24687008.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tbl_format["hsc_p"]["Mode"] = 90
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# ...

# %%
for columnName in quan:
    tbl_format[columnName]["Mean"] = dataset[columnName].mean()
    tbl_format[columnName]["Median"] = dataset[columnName].median()
    tbl_format[columnName]["Mode"] = dataset[columnName].mode()[0]

tbl_format
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4852\2573701546.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tbl_format[columnName]["Mean"] = dataset[columnName].mean()
# ...

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
import numpy as np
np.percentile(dataset["ssc_p"], 25)
# Out:
# 60.599999999999994

# %%
tbl_format_1 = pd.DataFrame(index=["Mean", "Median", "Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%"], columns = quan)
tbl_format_1
# Out:
#         sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean      NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode      NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1:25%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2:50%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3:75%    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4:100%   NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
for columnName in quan:
    tbl_format_1[columnName]["Mean"] = dataset[columnName].mean()
    tbl_format_1[columnName]["Median"] = dataset[columnName].median()
    tbl_format_1[columnName]["Mode"] = dataset[columnName].mode()[0]
    #Salary column remains Nan , because Nan value is present in the salary column in the dataset
    tbl_format_1[columnName]["Q1:25%"] = np.percentile(dataset[columnName], 25)
    tbl_format_1[columnName]["Q2:50%"] = np.percentile(dataset[columnName], 50)
    tbl_format_1[columnName]["Q3:75%"] = np.percentile(dataset[columnName], 75)
    tbl_format_1[columnName]["Q4:100%"] = np.percentile(dataset[columnName], 100)
    #So we accesing the salary value from the table directly dataset.describe
    tbl_format_1[columnName]["Q1:25%"] = dataset.describe()[columnName]["25%"]
    tbl_format_1[columnName]["Q2:50%"] = dataset.describe()[columnName]["50%"]
    tbl_format_1[columnName]["Q3:75%"] = dataset.describe()[columnName]["75%"]
    tbl_format_1[columnName]["Q4:100%"] = dataset.describe()[columnName]["max"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4852\2319874603.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tbl_format_1[columnName]["Mean"] = dataset[columnName].mean()
# ...

# %%
tbl_format_1
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
#
#                 salary
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       940000.0

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %% [markdown]
# #IQR

# %%
tbl_format_IQR = pd.DataFrame(index=["Mean", "Median", "Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR", "1.5IQR","LesserOutlier","GreaterOutlier","min","max"], columns = quan)
tbl_format_IQR
# Out:
#                sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean             NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median           NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode             NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1:25%           NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2:50%           NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3:75%           NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4:100%          NaN   NaN   NaN      NaN     NaN   NaN    NaN
# IQR              NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 1.5IQR           NaN   NaN   NaN      NaN     NaN   NaN    NaN
# LesserOutlier    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# GreaterOutlier   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# min              NaN   NaN   NaN      NaN     NaN   NaN    NaN
# max              NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
for columnName in quan:
    tbl_format_IQR[columnName]["Mean"] = dataset[columnName].mean()
    tbl_format_IQR[columnName]["Median"] = dataset[columnName].median()
    tbl_format_IQR[columnName]["Mode"] = dataset[columnName].mode()[0]
   
    #So we accesing the salary value from the table directly dataset.describe
    tbl_format_IQR[columnName]["Q1:25%"] = dataset.describe()[columnName]["25%"]
    tbl_format_IQR[columnName]["Q2:50%"] = dataset.describe()[columnName]["50%"]
    tbl_format_IQR[columnName]["Q3:75%"] = dataset.describe()[columnName]["75%"]
    tbl_format_IQR[columnName]["Q4:100%"] = dataset.describe()[columnName]["max"]
    #IQR = Q3-Q1
    tbl_format_IQR[columnName]["IQR"] = tbl_format_IQR[columnName]["Q3:75%"] - tbl_format_IQR[columnName]["Q1:25%"]
    tbl_format_IQR[columnName]["1.5IQR"] = 1.5 * tbl_format_IQR[columnName]["IQR"]
    #Lesser = Q1-1.5IQR
    tbl_format_IQR[columnName]["LesserOutlier"] = tbl_format_IQR[columnName]["Q1:25%"] - tbl_format_IQR[columnName]["1.5IQR"]
    #Lesser = Q3+1.5IQR
    tbl_format_IQR[columnName]["GreaterOutlier"] = tbl_format_IQR[columnName]["Q3:75%"] + tbl_format_IQR[columnName]["1.5IQR"]
    tbl_format_IQR[columnName]["min"] = dataset.describe()[columnName]["min"]
    tbl_format_IQR[columnName]["max"] = dataset.describe()[columnName]["max"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4852\3911675600.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tbl_format_IQR[columnName]["Mean"] = dataset[columnName].mean()
# ...

# %%
tbl_format_IQR
# Out:
#                 sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean            108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median          108.0       67.0       65.0       66.0       71.0       62.0
# Mode                1       62.0       63.0       65.0       60.0       56.7
# Q1:25%           54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%          108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%          161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%         215.0       89.4       97.7       91.0       98.0      77.89
# IQR             107.0       15.1       12.1       11.0       23.5       8.31
# 1.5IQR          160.5      22.65      18.15       16.5      35.25     12.465
# LesserOutlier  -106.0      37.95      42.75       44.5      24.75      45.48
# GreaterOutlier  322.0      98.35      91.15       88.5     118.75      78.72
# ...
